# %%
# %pip install ultralytics ipywidgets
# Out:
# Running cells with '.venv (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/mnt/e/synthetic-data-generation/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
/mnt/e/synthetic-data-generation/.venv/bin/python -m ensurepip --upgrade
# Out:
# Running cells with '.venv (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/mnt/e/synthetic-data-generation/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
